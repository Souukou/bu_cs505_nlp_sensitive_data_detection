# %%
from llama_cpp import Llama

llm = Llama(model_path="/home/yuhangs/code/llama.cpp/models/llama-2-13b.Q6_K.gguf", n_ctx=2048, n_gpu_layers=15000)

# %%
output = llm(
      "Q: Name the planets in the solar system? A: ", # Prompt
      max_tokens=320, # Generate up to 32 tokens

      stop=["Q:", "\n"], # Stop generating just before the model would generate a new question

      echo=True # Echo the prompt back in the output
)


print(output['choices'][0]['text'])
# Out:
# Q: Name the planets in the solar system? A: 24.
# llama_print_timings:        load time =     343.30 ms
# llama_print_timings:      sample time =       0.48 ms /     4 runs   (    0.12 ms per token,  8421.05 tokens per second)
# llama_print_timings: prompt eval time =     343.09 ms /    15 tokens (   22.87 ms per token,    43.72 tokens per second)
# llama_print_timings:        eval time =      88.00 ms /     3 runs   (   29.33 ms per token,    34.09 tokens per second)
# llama_print_timings:       total time =     438.17 ms

# %%
output = llm(
      '''Dataaset of lines of Python code which hardcoded sensitive information:
1:email_password = "myEmailPassword!"
2:aws_secret_key = "ABCD1234567890XYZ"
3:private_key = "MIIEvQIBADANBgkqhkiG9w0BAQEFAASC..."
4:ftp_username = "ftp_user"
5:ftp_password = "ftpPass123!"
6:db_uri = "postgres://dbuser:dbpass@localhost:5432/mydb"
7:access_token = "ghp_19C80752FsHyH56LlfC00JZLl0c8f2"
8:encryption_key = "a1b2c3d4e5f6g7h8"
''', # Prompt
      max_tokens=2048, # Generate up to 32 tokens

      # stop=["Q:", "\n"], # Stop generating just before the model would generate a new question

      echo=True # Echo the prompt back in the output
)


print(output['choices'][0]['text'])
# Out:
# Llama.generate: prefix-match hit
# Dataaset of lines of Python code which hardcoded sensitive information:
# 1:email_password = "myEmailPassword!"
# 2:aws_secret_key = "ABCD1234567890XYZ"
# 3:private_key = "MIIEvQIBADANBgkqhkiG9w0BAQEFAASC..."
# 4:ftp_username = "ftp_user"
# 5:ftp_password = "ftpPass123!"
# 6:db_uri = "postgres://dbuser:dbpass@localhost:5432/mydb"
# 7:access_token = "ghp_19C80752FsHyH56LlfC00JZLl0c8f2"
# 8:encryption_key = "a1b2c3d4e5f6g7h8"
# 9:token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..."
# 10:aws_region = 'us-east-1'
# 11:api_key = "a234bcdf"
# 12:password = 'abcdefghijklmnopqrstuvwxyz'
# 13:secret_token = '12345678901234567890123456789'
# 14:token = "myToken"
# 15:username = "testuser"
# 16:password = "myPassword"
# 17:api_key = "someKey"
# 18:database_name = 'myDatabase'
# 19:password = "secretPassword!"
# 20:port = 31415
# 21:username = "testuser"
# 22:password = "password"
# 23:api_key = "abcdefg"
# 24:password = "testuser123"
# ...

# %%
output = llm(
      '''Dataaset of lines of Python code which hardcoded sensitive information, Do not repeat, create more diversed data, the fake tokens should be more random, do not generate comments:
1/100,email_password = "myEmailPassword!"
2/100,aws_secret_key = "ABCD1234567890XYZ"
3/100,private_key = "MIIEvQIBADANBgkqhkiG9w0BAQEFAASC..."
4/100,ftp_username = "ftp_user"
5/100,ftp_password = "ftpPass123!"
6/100,db_uri = "postgres://dbuser:dbpass@localhost:5432/mydb"
7/100,access_token = "ghp_19C80752FsHyH56LlfC00JZLl0c8f2"
8/100,encryption_key = "a1b2c3d4e5f6g7h8"
''', # Prompt
      max_tokens=512, # Generate up to 32 tokens

      # stop=["Q:", "\n"], # Stop generating just before the model would generate a new question

      echo=True # Echo the prompt back in the output
)


print(output['choices'][0]['text'])
# Out:
# Llama.generate: prefix-match hit
# Dataaset of lines of Python code which hardcoded sensitive information, Do not repeat, create more diversed data, the fake tokens should be more random, do not generate comments:
# 1/100,email_password = "myEmailPassword!"
# 2/100,aws_secret_key = "ABCD1234567890XYZ"
# 3/100,private_key = "MIIEvQIBADANBgkqhkiG9w0BAQEFAASC..."
# 4/100,ftp_username = "ftp_user"
# 5/100,ftp_password = "ftpPass123!"
# 6/100,db_uri = "postgres://dbuser:dbpass@localhost:5432/mydb"
# 7/100,access_token = "ghp_19C80752FsHyH56LlfC00JZLl0c8f2"
# 8/100,encryption_key = "a1b2c3d4e5f6g7h8"
# 9/100,username = "admin"
# 10/100,password = "123456"
# 11/100,admin_user = "root"
# 12/100,password = "12345678!"
# 13/100,db_username = "dbadmin"
# 14/100,db_password = "dbpass123456"
# 15/100,token = "token-123456"
# 16/100,email = "my@email.com"
# 17/100,username = "admin"
# 18/100,password = "secret"
# 19/100,db_username = "dbuser"
# 20/100,db_password = "dbpass"
# ...

# %%
from llama_cpp import Llama

llm = Llama(model_path="/home/yuhangs/code/llama.cpp/models/llama-2-13b-chat.Q8_0.gguf", n_gpu_layers=15000)
# Out:
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: NVIDIA A100 80GB PCIe, compute capability 8.0
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /home/yuhangs/code/llama.cpp/models/llama-2-13b-chat.Q8_0.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# ...

# %%
output = llm(
      '''Generate code which hardcoded sensitive information like below, Create more diversed data, the fake tokens should be more random, also make the fake password/tokens/urls/username/db names looks more realistic, not look so fake. 
email_password = "yPn4f9b(0d#OU^CT!"
aws_secret_key = "1ag8Ef1w0iNkK8Al35fw"
private_key = "MIIEvQIBADANBgkqhkiG9w0BAQEFAA"
ftp_username = "ftp_user"
ftp_password = "09cewD4nvwBH4fwc2KYW"
ftp_password = "ftpPass123!"
db_uri = "postgres://backend_dbuser:2QfD98TBa37rZj8xBxZT@localhost:5432/financedb"
access_token = "ghp_19C80752FsHyH56LlfC00JZLl0c8f2"
encryption_key = "sJlsTOY967d9niGfpAUG2RJnnMhCtkiy"
''', # Prompt
      max_tokens=512, # Generate up to 32 tokens

      stop=["Q:"], # Stop generating just before the model would generate a new question

      echo=True # Echo the prompt back in the output
)


print(output['choices'][0]['text'])
# Out:
# Llama.generate: prefix-match hit
# Generate code which hardcoded sensitive information like below, Create more diversed data, the fake tokens should be more random, also make the fake password/tokens/urls/username/db names looks more realistic, not look so fake.
# email_password = "yPn4f9b(0d#OU^CT!"
# aws_secret_key = "1ag8Ef1w0iNkK8Al35fw"
# private_key = "MIIEvQIBADANBgkqhkiG9w0BAQEFAA"
# ftp_username = "ftp_user"
# ftp_password = "09cewD4nvwBH4fwc2KYW"
# ftp_password = "ftpPass123!"
# db_uri = "postgres://backend_dbuser:2QfD98TBa37rZj8xBxZT@localhost:5432/financedb"
# access_token = "ghp_19C80752FsHyH56LlfC00JZLl0c8f2"
# encryption_key = "sJlsTOY967d9niGfpAUG2RJnnMhCtkiy"
#
# to generate more diversed data, we can use a combination of the following techniques:
#
# 1. Use a random password generator to generate more realistic passwords.
# 2. Use a wordlist to generate more diverse and realistic usernames and domain names.
# ...
